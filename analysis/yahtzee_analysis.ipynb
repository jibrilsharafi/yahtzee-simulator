# %%
import concurrent.futures
import multiprocessing
import time
from typing import Dict
import sys

import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

sys.path.append("..")

from src.game.yahtzee_game import YahtzeeGame
from src.simulation.simulator import Simulator
from src.strategies.base_strategy import BaseStrategy
from src.strategies.random_strategy import RandomStrategy
from src.strategies.rule_based_strategy import RuleBasedStrategy
from src.strategies.expected_value_strategy import ExpectedValueStrategy
from src.strategies.expected_value_v2_strategy import ExpectedValueV2Strategy

# %%
def run_parallel_simulations(
    num_games: int, strategies: Dict[str, BaseStrategy], num_workers: int = None, use_parallel: bool = True
):
    """
    Run multiple Yahtzee game simulations in parallel or sequentially

    Args:
        num_games: Total number of games to simulate
        num_workers: Number of parallel workers (defaults to CPU count if None)
        use_parallel: Whether to use parallel processing

    Returns:
        Combined dictionary of win counts by player
    """
    # Use CPU count if num_workers is not specified
    if num_workers is None and use_parallel:

        num_workers = multiprocessing.cpu_count()

    start_time = time.time()

    if use_parallel:
        # Parallel execution
        games_per_worker = num_games // num_workers

        # Define the task for each worker
        def simulation_task():
            simulator = Simulator()
            return simulator.run_game_simulation(games_per_worker, strategies)

        # Run simulations in parallel
        combined_results = {player: 0 for player in strategies}
        with concurrent.futures.ProcessPoolExecutor(
            max_workers=num_workers
        ) as executor:
            futures = [executor.submit(simulation_task) for _ in range(num_workers)]
            for future in concurrent.futures.as_completed(futures):
                result = future.result()
                for player, wins in result.items():
                    combined_results[player] += wins
    else:
        # Sequential execution
        simulator = Simulator()
        combined_results = simulator.run_game_simulation(num_games, strategies)

    end_time = time.time()
    print(f"Simulation completed in {end_time - start_time:.2f} seconds")
    print(
        f"Mode: {'Parallel' if use_parallel else 'Sequential'}, Workers: {num_workers if use_parallel else 1}"
    )

    return combined_results

# %%
def collect_detailed_stats(
    num_games: int, strategies: Dict[str, BaseStrategy]
) -> pd.DataFrame:
    all_game_stats = []

    for game_num in range(num_games):
        game = YahtzeeGame()

        # Add players to the game
        for player_name in strategies:
            game.add_player(player_name)

        # Create dictionary to track scores
        player_scores = {player_name: [] for player_name in strategies}

        # Play through each turn manually to collect data
        for turn in range(13):  # Yahtzee has 13 turns
            for i, player in enumerate(game.players):
                player_name = (
                    player.name
                )  # Assuming Player objects have a name attribute
                initial_score = player.scorecard.get_total_score()

                # Use strategy to make moves
                strategy = strategies[player_name]
                game.play_turn(strategy)

                # Record score change
                new_score = player.scorecard.get_total_score()
                player_scores[player_name].append(new_score - initial_score)

        winner = game.determine_winner()
        final_scores = {
            player.name: player.scorecard.get_total_score() for player in game.players
        }

        for player_name in strategies:
            game_data = {
                "game": game_num,
                "player": player_name,
                "strategy": player_name,
                "final_score": final_scores[player_name],
                "winner": player_name == winner,
                "score_progression": player_scores[player_name],
            }
            all_game_stats.append(game_data)

    return pd.DataFrame(all_game_stats)

# %%
# Compare strategies across different categories
def analyze_category_performance(
    num_games: int, strategies: Dict[str, BaseStrategy]
) -> pd.DataFrame:
    category_stats = []

    for _ in range(num_games):
        for strategy_name, strategy in strategies.items():
            simulator = Simulator()
            game = YahtzeeGame()
            game.add_player("Player")

            # Play full game with this strategy
            game.play_game({"Player": strategy})

            # Extract category scores
            scorecard = game.players[0].scorecard  # Access the first player
            for category, score in scorecard.scores.items():
                if score is not None:  # Only include categories that were used
                    category_stats.append(
                        {
                            "strategy": strategy_name,
                            "category": category.value,
                            "score": score,
                        }
                    )

    return pd.DataFrame(category_stats)

# %%
# Run 1000 games with 4 parallel workers
N_SIMULATIONS = 100
USE_PARALLEL = False  # Set to True for parallel execution

STRATEGIES = {
    "Rule-Based": RuleBasedStrategy(),
    "Random": RandomStrategy(),
    "Expected Value": ExpectedValueStrategy(),
    "Expected Value V2": ExpectedValueV2Strategy(),
}

win_counts = run_parallel_simulations(
    N_SIMULATIONS, STRATEGIES, use_parallel=USE_PARALLEL
)

# Visualize win distribution
fig = px.pie(
    values=list(win_counts.values()),
    names=list(win_counts.keys()),
    title="Win Distribution by Strategy",
    color_discrete_sequence=px.colors.qualitative.Set3,
)
fig.show()

# Collect detailed stats for a smaller number of games

detailed_stats = collect_detailed_stats(N_SIMULATIONS, STRATEGIES)

# Visualize score distribution by strategy
fig = px.box(
    detailed_stats,
    x="strategy",
    y="final_score",
    color="strategy",
    title="Distribution of Final Scores by Strategy",
    points="all",
)
fig.show()

# Visualize score progression
avg_progression = (
    detailed_stats.groupby(["strategy"])
    .apply(
        lambda x: pd.DataFrame(
            {
                turn: [scores[turn] for scores in x["score_progression"]]
                for turn in range(13)
            }
        ).mean()
    )
    .reset_index()
)

# Reshape for plotting
progression_data = []
for _, row in avg_progression.iterrows():
    strategy = row["strategy"]
    for turn in range(13):
        progression_data.append(
            {"strategy": strategy, "turn": turn + 1, "avg_score": row[turn]}
        )

progression_df = pd.DataFrame(progression_data)

# Create line plot
fig = px.line(
    progression_df,
    x="turn",
    y="avg_score",
    color="strategy",
    title="Average Points Scored Per Turn",
    labels={"turn": "Turn Number", "avg_score": "Average Points"},
)
fig.show()

# Run analysis
category_performance = analyze_category_performance(N_SIMULATIONS, STRATEGIES)

# Visualize category performance
fig = px.box(
    category_performance,
    x="category",
    y="score",
    color="strategy",
    facet_col="strategy",
    title="Score Distribution by Category and Strategy",
)
fig.update_xaxes(tickangle=45)
fig.show()
# Out:
# Initializing lookup tables for ExpectedValueStrategy...
# Computing third roll values...
# Computing second roll values...
# Computing first roll values...
# Lookup tables initialized!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 12
#       3 USE_PARALLEL = False  # Set to True for parallel execution
#       5 STRATEGIES = {
#       6     "Rule-Based": RuleBasedStrategy(),
#       7     "Random": RandomStrategy(),
#       8     "Expected Value": ExpectedValueStrategy(),
#       9     "Expected Value V2": ExpectedValueV2Strategy(),
#      10 }
# ---> 12 win_counts = run_parallel_simulations(
#      13     N_SIMULATIONS, STRATEGIES, use_parallel=USE_PARALLEL
#      14 )
#      16 # Visualize win distribution
#      17 fig = px.pie(
#      18     values=list(win_counts.values()),
#      19     names=list(win_counts.keys()),
#      20     title="Win Distribution by Strategy",
#      21     color_discrete_sequence=px.colors.qualitative.Set3,
#      22 )
#
# Cell In[2], line 44, in run_parallel_simulations(num_games, strategies, num_workers, use_parallel)
#      41 else:
#      42     # Sequential execution
#      43     simulator = Simulator()
# ---> 44     combined_results = simulator.run_game_simulation(num_games, strategies)
#      46 end_time = time.time()
#      47 print(f"Simulation completed in {end_time - start_time:.2f} seconds")
#
# File c:\Users\jibri\Documents\GitHub\yahtzee-simulator\analysis\..\src\simulation\simulator.py:58, in Simulator.run_game_simulation(self, num_games, strategies)
#      55 for player_name in strategies:
#      56     game.add_player(player_name)
# ---> 58 game.play_game(strategies)
#      59 winner = game.determine_winner()
#      60 wins[winner] = wins.get(winner, 0) + 1
#
# File c:\Users\jibri\Documents\GitHub\yahtzee-simulator\analysis\..\src\game\yahtzee_game.py:95, in YahtzeeGame.play_game(self, strategies)
#      93 strategy = strategies.get(current_player.name)
#      94 if strategy:
# ---> 95     self.play_turn(strategy)
#
# File c:\Users\jibri\Documents\GitHub\yahtzee-simulator\analysis\..\src\game\yahtzee_game.py:73, in YahtzeeGame.play_turn(self, strategy)
#      70 if self.roll_count >= 3:
#      71     break
# ---> 73 dice_to_keep = strategy.select_dice_to_keep(
#      74     self.current_roll, self.get_current_player().scorecard
#      75 )
#      76 if len(dice_to_keep) == 5:  # Player wants to keep all dice
#      77     break
#
# File c:\Users\jibri\Documents\GitHub\yahtzee-simulator\analysis\..\src\strategies\expected_value_v2_strategy.py:203, in ExpectedValueV2Strategy.select_dice_to_keep(self, current_dice, scorecard, debug, top_n)
#     200 kept_dice = [current_dice[i] for i in keep_indices]
#     202 # Calculate EV for this keep decision
# --> 203 keep_ev = self._calculate_ev_for_roll(
#     204     kept_dice, scorecard.current_roll, available_categories
#     205 )
#     207 # Add to all decisions
#     208 all_decisions.append((keep_indices, kept_dice, keep_ev))
#
# File c:\Users\jibri\Documents\GitHub\yahtzee-simulator\analysis\..\src\strategies\expected_value_v2_strategy.py:113, in ExpectedValueV2Strategy._calculate_ev_for_roll(self, kept_dice, roll_number, available_categories)
#     109         outcome_score = float(
#     110             self._calculate_max_score(complete_dice, available_categories)
#     111         )
#     112     else:  # This is roll 1, we need to find the optimal keep decision for roll 2
# --> 113         outcome_score = self._find_best_keep_decision(
#     114             complete_dice, roll_number + 1, available_categories
#     115         )
#     117     total_score += outcome_score
#     119 # Calculate the expected value and cache it
#
# File c:\Users\jibri\Documents\GitHub\yahtzee-simulator\analysis\..\src\strategies\expected_value_v2_strategy.py:149, in ExpectedValueV2Strategy._find_best_keep_decision(self, current_dice, next_roll_number, available_categories)
#     146 kept_dice = [current_dice[i] for i in keep_indices]
#     148 # Calculate EV for this keep decision
# --> 149 keep_ev = self._calculate_ev_for_roll(
#     150     kept_dice, next_roll_number, available_categories
#     151 )
#     153 # Update our best EV if this is better
#     154 if keep_ev > best_ev:
#
# File c:\Users\jibri\Documents\GitHub\yahtzee-simulator\analysis\..\src\strategies\expected_value_v2_strategy.py:87, in ExpectedValueV2Strategy._calculate_ev_for_roll(self, kept_dice, roll_number, available_categories)
#      84     return self._calculate_max_score(kept_dice, available_categories)
#      86 # Create cache key
# ---> 87 dice_key = self._dice_key(kept_dice)
#      88 categories_key = self._available_categories_key(available_categories)
#      89 cache_key = (dice_key, roll_number, categories_key)
#
# File c:\Users\jibri\Documents\GitHub\yahtzee-simulator\analysis\..\src\strategies\expected_value_v2_strategy.py:46, in ExpectedValueV2Strategy._dice_key(self, dice)
#      44 if not dice:
#      45     return (0, 0, 0, 0, 0, 0)
# ---> 46 counts = Counter(dice)
#      47 return tuple(counts.get(i, 0) for i in range(1, 7))
#
# File c:\Python312\Lib\collections\__init__.py:607, in Counter.__init__(self, iterable, **kwds)
#     596 '''Create a new, empty Counter object.  And if given, count elements
#     597 from an input iterable.  Or, initialize the count from another mapping
#     598 of elements to their counts.
#    (...)
#     604
#     605 '''
#     606 super().__init__()
# --> 607 self.update(iterable, **kwds)
#
# File c:\Python312\Lib\collections\__init__.py:669, in Counter.update(self, iterable, **kwds)
#     657 @classmethod
#     658 def fromkeys(cls, iterable, v=None):
#     659     # There is no equivalent method for counters because the semantics
#    (...)
#     664     # more exotic cases, create a dictionary first using a dictionary
#     665     # comprehension or dict.fromkeys().
#     666     raise NotImplementedError(
#     667         'Counter.fromkeys() is undefined.  Use Counter(iterable) instead.')
# --> 669 def update(self, iterable=None, /, **kwds):
#     670     '''Like dict.update() but add counts instead of replacing them.
#     671
#     672     Source can be an iterable, a dictionary, or another Counter instance.
#    (...)
#     680
#     681     '''
#     682     # The regular dict.update() operation makes no sense here because the
#     683     # replace behavior results in some of the original untouched counts
#     684     # being mixed-in with all of the other counts for a mismash that
#     685     # doesn't have a straight-forward interpretation in most counting
#     686     # contexts.  Instead, we implement straight-addition.  Both the inputs
#     687     # and outputs are allowed to contain zero and negative counts.
#
# KeyboardInterrupt:
